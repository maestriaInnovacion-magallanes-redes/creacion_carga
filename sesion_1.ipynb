# %% [markdown]
# <center><img src="https://github.com/MAGALLANESJoseManuel/MGPIT_Pol748_Redes_1/blob/main/picsForSession/logoHeader.png?raw=true" width="800"></center>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/maestriaInnovacion-magallanes-redes/creacion_carga/blob/main/sesion_1-Code.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
#
#
# # Creación de redes y carga de data

# %% [markdown]
# <img align="right" width="500" height="100" src="https://github.com/MAGALLANESJoseManuel/MGPIT_Pol748_Redes_1/blob/main/picsForSession/logosNetSW.png?raw=true">
#
# Para trabajar con grafos (redes) hay una serie de programas que podemos utilizar. La gran diferencia radica en el tamaño del archivo que pueden manejar (complejidad de la red), en el costo del programa, la cantidad y actualización de funciones (algoritmos) implementados, y en si requieren o no programación.
#
#
#
# ## **ESTRUCTURA DE DATOS**
#
# Veamos la imagen de un grafo en [wikipedia](https://en.wikipedia.org/wiki/Graph_(discrete_mathematics)):
#
# <img src="https://github.com/MAGALLANESJoseManuel/MGPIT_Pol748_Redes_1/raw/main/picsForSession/grafo1.png"/>

# %% [markdown]
# De aquí notamos dos componentes básicos:
# * los nodos (_vertex_): `6`,`4`,`5`,`1`,`2`,`3`
# * los enlaces (_edges_): `6-4`,`4-5`,`4-3`,`5-2`,`5-1`,`2-3`,`2-1`
#
# Los nodos y enlaces podemos representados en una matriz, donde una celda tenga una marca (`1`) que indique si hay enlace entre los nodos. La gráfica debajo muestra esa matriz:

# %% [markdown]
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/redBasica_adjacency.jpg"/>

# %% [markdown]
# Otra manera sería escribir en dos columnas el origen y destino, es decir, los dos nodos que estén conectados por un enlace. La imagen que sigue representa ello:

# %% [markdown]
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/redBasica_edgelist.jpg"/>

# %% [markdown]
# Los enlaces mostrados no tienen direccionalidad (flechas), pero pueden tenerla cuando queramos tener un grafo dirigido. Las redes son grafos, pero "red" es una palabra más familiar que usaremos en nuestras sesiones. Las estructuras de matriz o lista de vertices  son compatibles en general, pero el _edgelist_, aun siendo más eficiente, suele no mostrar los nodos de la población bajo estudio que no tenga conexiones con otro nodo (_isolates_).
#
# > ¿Cómo podemos crear esta red en la computadora?
# Redes pequeñas de este tipo pueden crearse manualmente usando, por ejemplo, Python. Para usar Python, puede instalarlo localmente (en su computadora), se recomienda [ANACONDA](https://www.anaconda.com/download)).
# Ello no es necesario si desea usar la versión de Python que ofrece GOOGLE, [Colab](https://colab.research.google.com/).

# %% [markdown]
# ## Creando una red

# %%
# _Networkx_ es una librería de Python

import networkx as nx

red1 = nx.Graph()
red1.add_edges_from([(6,4),(4,5),(4,3),(5,2),(5,1),(2,3),(2,1)])

# %%
red1.nodes()

# %%
red1.edges()

# %% [markdown]
# # LECTURA DE ARCHIVOS

# %% [markdown]
# La creación manual no es comun en estos día. Generalmente necesitamos preparar datos en archivos que luego sean leidos por otro software o librería especializada. Hay que saber elegir la estructura y la herramienta apropiada para crear una red. Por ejemplo, en [esta hoja de calculo](https://docs.google.com/spreadsheets/u/6/d/e/2PACX-1vReqFHgPvGpZiSozcooJkZOH7kOCvtpgtq0fvuIehQ6MfqM-To93umwRY0pJBZzoCetj_ptmLCpNnGv/pubhtml) podemos ver los datos que utilizó Adolfo Figueroa en su [artículo](https://doi.org/10.1016/j.qref.2006.12.016) "_Competition and circulation of economic elites: Theory and application to the case of Peru_" del 2007, en dos formatos, la matriz de adyacencia (**adjancency matrix**) y la lista de enlaces (**edgelist**). La matriz de adyacencia tiene esta apariencia:

# %% [markdown]
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/red_figue_adj.jpg"/>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# Para esta sección, dirigete a este **[enlace](https://drive.google.com/drive/folders/1ycEE-r-LGyCpQl8bcUOCR4lNlVWj14E8?usp=sharing)**, el acceso es con la cuenta _@pucp.edu.pe_.
#
# Simplemente, abre el archivo y crea UNA COPIA en tu propio google drive.
# </div>

# %% [markdown]
# ## Usando NETWORKX
#
#
# Python y Networkx pueden leer la data desde Google Drive. Sigamos estos pasos:
#
# * Paso 1: _Compartir_ y _Publicar_ tabla en la web:
#
# <img src="picsForSession/Drive_step1.jpg" width="300"/>
#
# * Paso 2: Obtener el link
#
# <img src="picsForSession/Drive_step2.jpg" width="300"/>
#
# La <ins>primera vez</ins> que haga el paso 2, debe presionar la opción "_Publicar_" (aqui ya aparece como _"Publicado"_)
#
# A continuación, si está usando Python, puede guardar el link en Python de manera sencilla:

# %%
# link a google sheets entre "comillas" 
LinkToGoogle="https://docs.google.com/spreadsheets/d/e/2PACX-1vReqFHgPvGpZiSozcooJkZOH7kOCvtpgtq0fvuIehQ6MfqM-To93umwRY0pJBZzoCetj_ptmLCpNnGv/pub?output=xlsx"

# %% [markdown]
# Leamos la matriz de adyacencia en Python, para lo cual primero leemos la tabla usando el link en con la libreria _pandas_:

# %%
# leyendo matriz de adyacencia

import pandas as pd

adjacency=pd.read_excel(LinkToGoogle, # link a la tabla
                        index_col=0,  # la columna '0' guarda los nombres
                        sheet_name='adjacency') # la tabla tiene este nombre

# %% [markdown]
# El objeto **adjancency** guarda la tabla. Ahora usamos __from_pandas_adjacency()__ de la librería **networkx**, y se crea la red:

# %%
# crear red
eliteFromAdjacency=nx.from_pandas_adjacency(adjacency)

# %% [markdown]
# La red ya está creada, veamos:

# %%
# nodos de la red
eliteFromAdjacency.nodes()

# %%
# enlaces de la red
eliteFromAdjacency.edges()

# %% [markdown]
# Si quisieramos usar el _edgelist_, necesitamos:

# %%
edgeList=pd.read_excel(LinkToGoogle,
                        sheet_name='edgelist') # la tabla tiene este nombre

edgeList
# crear red
eliteFromEdgelist=nx.from_pandas_edgelist(edgeList,edge_attr=True)

# %% [markdown]
# Veamos la diferencia eentre ambas redes:
#
# * Cantidad de Nodos:

# %%
# 'len()' se usa para contar elementos
eliteFromAdjacency.number_of_nodes(), eliteFromEdgelist.number_of_nodes()

# %% [markdown]
# * Cantidad de enlaces:

# %%
eliteFromAdjacency.number_of_edges(), eliteFromEdgelist.number_of_edges()

# %% [markdown]
# * Las **islas** del _edgelist_:

# %%
list(nx.isolates(eliteFromEdgelist))

# %% [markdown]
# * Las islas del _adjacency_:

# %%
list(nx.isolates(eliteFromAdjacency))

# %% [markdown]
# La red **eliteFromEdgelist** puede completarse:

# %%
eliteFromEdgelist.add_nodes_from(['Lucioni', 'Rodriguez Rodríguez', 'Custer', 'Ikeda', 'Cogorno', 'Arias Davila'])

# %% [markdown]
# Ahora tiene los mismos nodos:

# %%
eliteFromEdgelist.number_of_nodes()

# %% [markdown]
# Y claro, sus islas:

# %%
list(nx.isolates(eliteFromEdgelist))

# %% [markdown]
# ### Exportación
#
# Las redes creadas con Networkx pueden exportarse en diferentes formatos, que serán útiles en otros programas. Aquí grabaremos en el formato GML y GRAPHML:

# %%
filename1='eliteFromAdjacency.gml' # nombre incluye 'donde'
filename2='eliteFromAdjacency.graphml'

# guardando:
nx.write_gml(eliteFromAdjacency,filename1)

nx.write_graphml(eliteFromAdjacency,filename2)

# %% [markdown]
# # VISUALIZACION DE REDES
#
# Es muy común producir gráficos de redes. La gráficas, si son bien hechas, pueden resaltar algunas propiedades de la red. No siempre es posible lograrlo cuando la red es muy grande y no muestra una estructura clara.
#
# ## Usando NETWORKX
#
# Tenemos activa la red _eliteFromAdjacency_. Visualizarla con Networkx es muy sencillo:

# %%
nx.draw(eliteFromAdjacency)

# %% [markdown]
# La ubicacion de los nodos sigue por lo general algun algoritmo, este es otro:

# %%
pos = nx.spiral_layout(eliteFromAdjacency) #algoritmo spiral
nx.draw(eliteFromAdjacency, pos=pos)

# %% [markdown]
# Hay muchos _layouts_ disponibles, los de Networkx puedes revisarlos [aquí](https://networkx.org/documentation/stable/reference/drawing.html#).

# %% [markdown]
# ## Usando GEPHI
#
# Gephi es un software de visualización y exploración de redes, de código abierto y gratuito. El Gephi debe instalarse en la computadora directamente desde su [página web](https://gephi.org/users/download/).
#
# Hasta aquí tenemos varios archivos:
#
# * Un excel con la matriz de adyacencia y el edgelist.
# * Un GML con la red ya creada en Python.
# * Un GRAPHML con la red ya creada en Python.
#
# > Estos archivos no se pueden leer desde Google, GEPHI sólo lo lee desde tu computadora. Puedes crear una carpeta para esta sesión, y descarga o mueve los archivos ahí.
#
# Veamos como abrir la matriz de adyacencia en Gephi:

# %% [markdown]
# 1. Abre GEPHI, y ve a la opcion **FILE** del menu superior, selecciona la opción indicada:
#
#
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/gephi_excel_adj1.jpg" width="300"/>

# %% [markdown]
# 2. Busca el archivo con la matriz de adyacencia y abrelo:
#
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/gephi_excel_adj2.jpg" width="500"/>

# %% [markdown]
# 3. Selecciona lo que corresponde, recuerda que que Excel puede haber varias hojas.
#
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/gephi_excel_adj3.jpg"/>

# %% [markdown]
# 4. En el paso siguiente, solo selecciona esta opción:
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/gephi_excel_adj4.jpg" width="500"/>

# %% [markdown]
# 5. En esta ventana, asegurate que **GRAPH TYPE** sea el correcto. Aqui debe ser UNDIRECTED. Asi mismo, crea un nuevo espacio de trabajo.
#
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/gephi_excel_adj5.jpg"/>

# %% [markdown]
# 6. Verifica que a esta altura,  tienes algo muy similar a esto:
#
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/gephi_excel_adj6.jpg"/>

# %% [markdown]
# > Los archivos creados por Python se abren directamente. Usemos el `GRAPHML`:
#
# paso 1:
#
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/gephi_graphml1.jpg" width="300"/>

# %% [markdown]
# paso 2:
#
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/gephi_graphml2.jpg" width="600"/>

# %% [markdown]
# paso 3:
#
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/gephi_graphml3.jpg" width="600"/>

# %% [markdown]
# Listo!
#
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/gephi_graphml4.jpg" width="600"/>

# %% [markdown]
# <div class="alert-success">
#
# ## Ejercicio 1
#
# En la red recién abierta en GEPHI (gml) juege con este menú
#
# <img src="https://github.com/maestriaInnovacion-magallanes-redes/creacion_carga/raw/main/picsForSession/gephi_node_edges_options.jpg" width="600"/>
#
# Y logre que se vea mejor los nombres de los nodos, algo así:
#
# <img src="picsForSession/readGRAPHML.png" width="900"/>
#
#
# </div>

# %% [markdown]
# ## En Python es algo sencillo

# %%
pos = nx.spiral_layout(eliteFromAdjacency) # algoritmo spiral
nx.draw(eliteFromAdjacency, pos=pos, with_labels=True)

# %% [markdown]
# Pero, saber los comandos a veces toma tiempo:

# %%
nx.draw(
    eliteFromAdjacency, 
    pos=pos, 
    with_labels=True, 
    node_color='lightblue',   # Cambia el color del nodo para que resalte el texto
    font_size=10,             # Ajusta el tamaño de la letra
    font_weight='bold',       # Hace la letra más legible
    node_size=500             # Agranda el nodo si el texto es muy largo
)

# %% [markdown]
# <div class="alert-success">
#
# ## Ejercicio 2
#
# ¿Cómo te aproximarías al gráfico anterior?
#
#
# </div>

# %% [markdown]
# <div class="alert-success">
#
# ## Ejercicio 3
#
# Para esta parte crearemos una red a partir de una historia ([VER AQUI](https://drive.google.com/file/d/1skvkhOhJHYyiW0LlteIbknkxcdJ5gh8d/view?usp=sharing)).
#
# En la historia, identifica:
# - nodos (cientifico)
# - enlaces (entre cientifico, quien conoció a quien)
#
# En un Excel crea una matriz de adyacencia o un edgelist usando lo anterior.
# Luego lo lees en Python, y creas la red.
# Esa red la exportala a GEPHI como archivo GML o GRAPHML.
# Una vez en Gephi, muestra la red con el nombre de sus nodos.
#
# </div>

# %% [markdown]
# ## Redes con 'edges' dirigidos
#
# Cuando creamos una red no-dirigida con:
# ```
# > ....add_edges_from([(6,4),(4,5),(4,3),(5,2),(5,1),(2,3),(2,1)])
# ```
#
# El edge (6,4) significa que (4,6) existe. La relación es recíproca o simétrica.
#
# Un grafo dirigido indica que la relación no es _necesariamente_ recíproca. Si no lo es, debemos crear un grafo o red dirigida:

# %%
red2 = nx.DiGraph()

red2.add_edges_from([(6,4),(4,5),(4,3),(5,2),(5,1),(2,3),(2,1)])

# cuales tenemos:
red2.edges()

# %% [markdown]
# En las redes dirigidas como la creada, `(6,4)` es diferente a `(4,6)`, entonces, si ambos edges existen, deben incluirse manera explícita.

# %%
# La forma rápida y directa
pos = nx.spiral_layout(red2) # algoritmo spiral
nx.draw(red2, with_labels=True, node_color="skyblue", pos=pos)

# %% [markdown]
# ### Ejemplo ficticio: Relaciones de asesoría en un departamento de Historia
#
# Todos los nodos son profesores del departamento. Los más antiguos fueron asesorados por figuras fundadoras, los de mediana edad por los antiguos, y los jóvenes por los de mediana edad. La red captura el linaje intelectual: quién formó a quién.
#
# | Generación            | Profesores                                                 | Años de doctorado |
# | --------------------- | ---------------------------------------------------------- | ----------------- |
# | **Fundadores** (1ª)   | Elena Vargas, Roberto Díaz                                 | 1980–1985         |
# | **Consolidados** (2ª) | Carlos Méndez, Ana Ruiz, Bruno Soto, Laura Vega            | 1995–2005         |
# | **Jóvenes** (3ª)      | Martín Herrera, Lucía Fernández, Sofía Reyes, Diego Ortega | 2015–2022         |
#
# Quien asesoró a quien:
#
# | Asesorado (más joven) | Asesor (más antiguo) | Año  | Tema de tesis                        |
# | --------------------- | -------------------- | ---- | ------------------------------------ |
# | Carlos Méndez         | Elena Vargas         | 1995 | Historia política comparada          |
# | Ana Ruiz              | Elena Vargas         | 1998 | Historia social del trabajo          |
# | Bruno Soto            | Roberto Díaz         | 2000 | Historia urbana latinoamericana      |
# | Laura Vega            | Roberto Díaz         | 2003 | Historia de la educación             |
# | Martín Herrera        | Carlos Méndez        | 2016 | Historia de los movimientos obreros  |
# | Lucía Fernández       | Carlos Méndez        | 2018 | Historia del sindicalismo            |
# | Sofía Reyes           | Ana Ruiz             | 2019 | Historia de género y familia         |
# | Diego Ortega          | Bruno Soto           | 2021 | Historia de las migraciones internas |
# | Diego Ortega          | Laura Vega           | 2021 | Metodología cualitativa (coasesoría) |

# %%
asesorias = nx.DiGraph()

# Todos son profesores del departamento
profesores = [
    "Elena Vargas", "Roberto Díaz",           # 1ª generación
    "Carlos Méndez", "Ana Ruiz", "Bruno Soto", "Laura Vega",  # 2ª generación
    "Martín Herrera", "Lucía Fernández", "Sofía Reyes", "Diego Ortega"  # 3ª
]
asesorias.add_nodes_from(profesores)

# Flecha: asesor → asesorado (dirección del legado intelectual)
asesorias.add_edges_from([
    # 1ª → 2ª generación
    ("Elena Vargas", "Carlos Méndez"),
    ("Elena Vargas", "Ana Ruiz"),
    ("Roberto Díaz", "Bruno Soto"),
    ("Roberto Díaz", "Laura Vega"),
    # 2ª → 3ª generación
    ("Carlos Méndez", "Martín Herrera"),
    ("Carlos Méndez", "Lucía Fernández"),
    ("Ana Ruiz", "Sofía Reyes"),
    ("Bruno Soto", "Diego Ortega"),
    ("Laura Vega", "Diego Ortega"),  # coasesoría
])

#veamos
print(asesorias)

# %%
nx.draw(asesorias,with_labels=True)

# %% [markdown]
# ## Redes bipartitas
#
# Un grafo bipartito es una red donde los nodos se dividen en dos grupos distintos (dos "equipos", dos "categorías"), y las conexiones solo existen entre grupos, nunca dentro del mismo grupo.
#
# No hay líneas que unan nodos del mismo grupo.

# %% [markdown]
# ### Ejemplo ficticio: Prestación de servicios profesionales
#
# En este ejemplo, los nodos son personas reales que ofrecen servicios especializados, y organizaciones (empresas cliente) que contratan esos servicios.
#
# * Conjunto U (10 nodos): profesionales independientes.
# * Conjunto W (3 nodos): empresas cliente que reciben el servicio.
#
# La relación es dirigida: persona → empresa significa "esta persona presta un servicio a esta empresa". La flecha indica la dirección del servicio, no del dinero.
#
# **Los profesionales**
#
#
# | Persona  | Especialidad           | Nota                                                   |
# | -------- | ---------------------- | ------------------------------------------------------ |
# | Ana      | Auditoría financiera   | Ex Big Four, ahora freelance                           |
# | Bruno    | Auditoría financiera   | Socio de Ana en algunos proyectos                      |
# | Carlos   | Auditoría financiera   | También hace consultoría de riesgos                    |
# | Diana    | Seguridad informática  | Especialista en pentesting                             |
# | Elena    | Seguridad informática  | Certificada en normativas ISO                          |
# | Federico | Seguridad informática  | Experto en respuesta a incidentes                      |
# | Gabriela | Seguridad informática  | La más senior del grupo, también asesora en compliance |
# | Hugo     | Desarrollo de software | Full-stack, recién independiente                       |
# | Isabel   | Desarrollo de software | Especialista en arquitectura cloud                     |
# | Javier   | Desarrollo de software | Enfocado en inteligencia artificial aplicada           |
#
# **empresas que reciben servicio**
#
# | Empresa       | Sector     | Servicio contratado                      |
# | ------------- | ---------- | ---------------------------------------- |
# | FinanzasCorp  | Financiero | Auditoría externa, revisión de estados   |
# | TechSecure    | Tecnología | Auditoría de seguridad, pentesting       |
# | InnovaDigital | Tecnología | Desarrollo a medida, consultoría técnica |
#
#
# **Edge list: quién presta servicio a quién**
#
# | Persona  | Empresa cliente | Servicio prestado                             |
# | -------- | --------------- | --------------------------------------------- |
# | Ana      | FinanzasCorp    | Auditoría anual de estados financieros        |
# | Bruno    | FinanzasCorp    | Revisión de procesos contables                |
# | Carlos   | FinanzasCorp    | Auditoría de riesgos operativos               |
# | Carlos   | TechSecure      | Consultoría de riesgos en ciberseguridad      |
# | Diana    | TechSecure      | Pentesting de infraestructura                 |
# | Elena    | TechSecure      | Auditoría de cumplimiento normativo ISO 27001 |
# | Federico | TechSecure      | Respuesta a incidente de seguridad            |
# | Gabriela | TechSecure      | Auditoría de seguridad integral               |
# | Gabriela | InnovaDigital   | Asesoría en compliance de datos               |
# | Hugo     | InnovaDigital   | Desarrollo de plataforma web                  |
# | Isabel   | InnovaDigital   | Migración de arquitectura a cloud             |
# | Javier   | InnovaDigital   | Desarrollo de módulo de IA                    |

# %%
from networkx.algorithms import bipartite

# 1. CREAMOS EL GRAFO DIRIGIDO BIPARTITO
red_servicios = nx.DiGraph()

# Conjunto U: profesionales (bipartite=0)
profesionales = [
    "Ana", "Bruno", "Carlos", "Diana", "Elena",
    "Federico", "Gabriela", "Hugo", "Isabel", "Javier"
]

# Conjunto W: empresas cliente (bipartite=1)
empresas = ["FinanzasCorp", "TechSecure", "InnovaDigital"]

red_servicios.add_nodes_from(profesionales, bipartite=0)
red_servicios.add_nodes_from(empresas, bipartite=1)

# EDGES DIRIGIDOS: profesional → empresa (presta servicio)
red_servicios.add_edges_from([
    # Auditores financieros → FinanzasCorp
    ("Ana", "FinanzasCorp"),
    ("Bruno", "FinanzasCorp"),
    ("Carlos", "FinanzasCorp"),
    # Carlos también asesora a TechSecure en riesgos
    ("Carlos", "TechSecure"),
    # Especialistas en seguridad → TechSecure
    ("Diana", "TechSecure"),
    ("Elena", "TechSecure"),
    ("Federico", "TechSecure"),
    ("Gabriela", "TechSecure"),
    # Gabriela también asesora a InnovaDigital en compliance
    ("Gabriela", "InnovaDigital"),
    # Desarrolladores → InnovaDigital
    ("Hugo", "InnovaDigital"),
    ("Isabel", "InnovaDigital"),
    ("Javier", "InnovaDigital"),
])

# que tenemos?
print(red_servicios,"¿Es bipartita la red?", bipartite.is_bipartite(red_servicios))

# %%
# 2. Configurar la disposición en dos columnas (bipartite_layout)
pos = nx.bipartite_layout(red_servicios, profesionales)

nx.draw(
    red_servicios,
    pos,
    with_labels=True, 
    node_color="skyblue")

# %% [markdown]
# > Una red bipartita conecta dos mundos distintos; pero a veces lo que nos interesa no es la relación cruzada, sino la relación dentro de uno de los dos mundos. La proyección es el proceso de colapsar la red bipartita en una red unipartita: conservamos solo los nodos de uno de los dos conjuntos, y conectamos dos nodos entre sí, si compartían al menos un vecino en el mundo opuesto.
#
# Aqui vemos la proyeccción de la `red_servicios` sobre los nodos de profesionales, ya es una red unipartita no dirigida, donde el edge representa `han dado servicios a la misma empresa`

# %%
red_unipartita = bipartite.projected_graph(red_servicios.to_undirected(), profesionales)

# 3. Graficar solo la red unipartita

pos = nx.spring_layout(red_unipartita, seed=42)

nx.draw(
    red_unipartita,
    pos,
    with_labels=True,
    node_color="orange",
    node_size=900,
    font_weight="bold",
    font_size=12,
    edge_color="dimgray",
    width=2,
)

# %% [markdown]
# <div class="alert-success">
#
# ## Ejercicio 4
#
# ### Parte 1
# Para esta parte crearemos una red a partir de esta historia ([VER AQUI](https://drive.google.com/file/d/11H1SdDwT4tKdqCFKeEwXwslVD3bcsdbk/view?usp=sharing)).
#
# En la historia, identifica nodos y enlaces. En un Excel crea una matriz de adyacencia o un edgelist usando lo anterior.
# Luego lo lees en Python, y creas la red, , si es una bipartita, proyectala a unipartita. Esa red la exportala a GEPHI como archivo GML o GRAPHML. Una vez en Gephi, muestra la red con el nombre de sus nodos.
#
# ### Parte 2
# Para esta parte crearemos una red a partir de esta historia ([VER AQUI](https://drive.google.com/file/d/1rCjhJu99BPm12jjST8ZNxqFCfxJ3cBOQ/view?usp=sharing)).
#
# En la historia, identifica nodos y enlaces. En un Excel crea una matriz de adyacencia o un edgelist usando lo anterior.
# Luego lo lees en Python, y creas la red, , si es una bipartita, proyectala a unipartita. Esa red la exportala a GEPHI como archivo GML o GRAPHML. Una vez en Gephi, muestra la red con el nombre de sus nodos.
#
# </div>
